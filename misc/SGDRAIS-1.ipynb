# %%
#======================================================================
#======================================================================
#                  MNIST
#======================================================================
#======================================================================

from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

num_classes = 10

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train_mnist, y_train_mnist), (x_test_mnist, y_test_mnist) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train_mnist = x_train_mnist.reshape(x_train_mnist.shape[0], 1, img_rows, img_cols)
    x_test_mnist = x_test_mnist.reshape(x_test_mnist.shape[0], 1, img_rows, img_cols)
    input_shape_mnist = (1, img_rows, img_cols)
else:
    x_train_mnist = x_train_mnist.reshape(x_train_mnist.shape[0], img_rows, img_cols, 1)
    x_test_mnist = x_test_mnist.reshape(x_test_mnist.shape[0], img_rows, img_cols, 1)
    input_shape_mnist = (img_rows, img_cols, 1)

x_train_mnist = x_train_mnist.astype('float32')
x_test_mnist = x_test_mnist.astype('float32')
x_train_mnist /= 255
x_test_mnist /= 255
print('x_train shape:', x_train_mnist.shape)
print(x_train_mnist.shape[0], 'train samples')
print(x_test_mnist.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_mnist = keras.utils.to_categorical(y_train_mnist, num_classes)
y_test_mnist = keras.utils.to_categorical(y_test_mnist, num_classes)
# Out:
# Using TensorFlow backend.
# DEBUG:matplotlib:$HOME=/home/jan
# DEBUG:matplotlib:matplotlib data path /usr/lib/python2.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /usr/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 2.2.3
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux2
# DEBUG:matplotlib:loaded modules: ['numpy.core.info', 'pandas._libs.numpy', 'traitlets.config.decorator', 'pandas.errors.pandas', 'tensorflow.python.eager.execute', 'tensorflow.python.keras.layers.recurrent', 'tensorflow.python.ops.nn_grad', 'pygments.filters', 'IPython.utils.pprint', 'matplotlib.cbook._backports', 'requests.Cookie', 'tensorflow.python.training.momentum', 'logging.weakref', 'dateutil.tz.os', 'pprint', 'prompt_toolkit.key_binding.bindings.vi', 'ipykernel.traitlets', 'requests.packages.chardet.euctwprober', 'tensorflow.core.protobuf.config_pb2', 'keras_applications.mobilenet_v2', 'IPython.terminal.sys', 'scipy.spatial._voronoi', 'numpy.core._multiarray_tests', 'chardet.mbcssm', 'encodings.re', 'IPython.terminal.embed', 'tensorflow.python.keras.engine.sequential', 'jupyter_core.sys', 'cmd', 'requests.packages.chardet.hebrewprober', 'IPython.core.magics.auto', 'shlex', 'multiprocessing.pool', 'tensorflow.python.training.proximal_adagrad', 'chardet.re', 'IPython.core.completerlib', 'tensorflow.python.ops.cond_v2_impl', 'zlib', 'pandas.core.indexes.numpy', 'urllib3.packages.ssl_match_hostname._implementation', 'pexpect.spawnbase', 'IPython.terminal.ipapp', 'tensorflow.python.ops.gen_spectral_ops', 'IPython.core.excolors', 'tensorflow.python.saved_model', 'tensorflow.python.data', 'scipy.sparse.csgraph._min_spanning_tree', 'numpy.testing._private.pytesttester', 'tensorflow.python.training', 'zmq.backend.cython.error', 'tensorflow.python.estimator.canned.dnn_linear_combined', 'pandas.plotting.contextlib', 'tarfile', 'IPython.core.mimetypes', 'ntpath', 'tensorflow.core.example.example_pb2', 'IPython.utils.openpy', 'tensorflow.python.training.checkpointable.layer_utils', 'pandas.io.formats.format', 'prompt_toolkit.key_binding.weakref', 'prompt_toolkit.tempfile', 'pandas.core.types', 'tensorflow.python.keras', 'codecs', 'traitlets.config.loader', 'scipy.linalg.decomp_cholesky', 'zmq.eventloop', 'scipy.interpolate._cubic', 'mmap', 'ptyprocess.errno', 'tensorflow.python.ops.nn_impl', 'pygments.filters.pygments', 'numpy.core._internal', 'pandas.io', 'IPython.core.usage', 'PIL.operator', 'requests.packages.chardet.langbulgarianmodel', 'tensorflow.python.data.ops.iterator_ops', 'tensorflow.python.framework.op_def_library', 'future.utils.sys', 'tensorflow.python.data.ops.optional_ops', 'ctypes._ctypes', '_heapq', 'zmq.sugar.constants', 'requests.packages.urllib3.util', 'tensorflow.python.keras.applications.mobilenet', 'pandas._libs.tslibs.timedeltas', 'pexpect.time', 'zmq.backend.cython._poll', 'email.sys', 'prompt_toolkit.filters.utils', 'dateutil.tz._common', 'requests.chardet', 'pandas.compat.StringIO', 'cPickle', 'h5py._errors', 'ipykernel.comm.ipykernel', 'unittest.sys', 'IPython.utils.encoding', 'keras_applications.inception_v3', 'tensorflow.python.ops.gen_boosted_trees_ops', 'IPython.lib.os', 'zmq.backend.cython.cPickle', 'pandas.core.accessor', 'pandas.core.dtypes.pandas', 'prompt_toolkit.enums', 'numpy.ctypeslib', 'tensorflow.python.ops.gradients', 'jupyter_client.sys', 'prompt_toolkit.styles.pygments', 'tensorflow.python.framework.tensor_spec', 'scipy._lib._util', 'yaml.resolver', 'zmq.backend.cython.codecs', 'jupyter_client.blocking.jupyter_client', 'distutils.sys', 'exceptions', 'requests.encodings', 'pandas.io.formats.locale', 'urllib3.util.functools', 'requests.packages.chardet.charsetprober', 'pygments.regexopt', 'scipy._lib.operator', 'logging.cStringIO', 'tensorflow.core.protobuf.saver_pb2', 'numpy.compat', 'dateutil.parser.__future__', 'chardet.version', 'tensorflow.python.ops.string_ops', 'tensorflow.python.estimator.inputs.numpy_io', 'pandas.tseries.datetime', 'numpy.core.records', 'email.message', 'ipykernel.zmq', 'urllib3.fields', 'email.MIMEBase', 'strop', 'IPython.core.history', 'concurrent.futures.process', 'ipython_genutils.textwrap', 'PIL.atexit', 'ipykernel._thread', 'prompt_toolkit.abc', 'IPython.utils.ipstruct', 'scipy.ndimage.io', 'pandas.core.arrays.pandas', 'requests.packages.chardet.gb2312freq' ...
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
#======================================================================
#======================================================================
#                  CIFAR 10
#======================================================================
#======================================================================

import tensorflow
import numpy as np
from keras import datasets

def load_cifar10_data():
    cifar10 = datasets.cifar10
    (x_train_cifar, y_train_cifar),(x_test_cifar, y_test_cifar) = cifar10.load_data()
    x_train_cifar = x_train_cifar.astype('float32') / 255.0
    x_test_cifar = x_test_cifar.astype('float32') / 255.0

    return (x_train_cifar, y_train_cifar), (x_test_cifar, y_test_cifar)

input_shape_cifar = (32, 32, 3)
train_cifar, test_cifar = load_cifar10_data()
x_train_cifar = train_cifar[0]
x_test_cifar = test_cifar[0]

y_train_cifar = keras.utils.to_categorical(train_cifar[1], num_classes)
y_test_cifar = keras.utils.to_categorical(test_cifar[1], num_classes)

# %%
from keras import backend as K
from keras.utils.generic_utils import serialize_keras_object
from keras.utils.generic_utils import deserialize_keras_object
from keras.legacy import interfaces
from keras.optimizers import Optimizer

def buildMnist():
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                   activation='relu',
                   input_shape=input_shape_mnist, padding='same'))
  model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(loss=keras.losses.categorical_crossentropy,
                optimizer=keras.optimizers.SGD(),
                metrics=['accuracy'])
  return model

# %%
from keras import backend as K
from keras.utils.generic_utils import serialize_keras_object
from keras.utils.generic_utils import deserialize_keras_object
from keras.legacy import interfaces
from keras.optimizers import Optimizer
from keras.layers import Dense, Dropout, Activation, Flatten

def buildCifar():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                     input_shape=x_train_cifar.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy,
                optimizer=keras.optimizers.SGD(),
                metrics=['accuracy'])
    
    return model

# %%
import logging
import numpy as np
logging.basicConfig(level=logging.DEBUG)

class OSGDTrainer():

    def __init__(self, model):
        self.model = model
        self.logger = logging.getLogger("OSGDTrainer")
    
        layer=-1
        grads = model.optimizer.get_gradients(model.total_loss, model.layers[layer].output)
        symb_inputs = (model._feed_inputs + model._feed_targets + model._feed_sample_weights)
        self.f_grads = K.function(symb_inputs, grads)
    
    def _get_grads(self, xs, ys):
        x, y, sample_weight = self.model._standardize_user_data(xs, ys)
        output_grad = self.f_grads(x + y + sample_weight)
        return output_grad

    def _get_distribution(self, xs, ys):
        n = xs.shape[0]
        k = 1000
        p = np.zeros(xs.shape[0])
        for i in range((n-1) // k + 1):
            fst = i*k
            snd = min(n, (i+1) * k)
            grads = self._get_grads(xs[fst:snd], ys[fst:snd])[0]
            v = np.linalg.norm(grads, axis=1)
            p[fst:snd] = v    
        return p / p.sum()

    def _test_on_validation(self, validation_data):
        valid_x, valid_y = validation_data
        loss, acc = self.model.test_on_batch(valid_x, valid_y)
        self.logger.info("========== Validation loss: " + str(loss) + " acc: " + str(acc))
        return [(loss, acc)]
      
    def train(self, train_x, train_y, batch_size=16, epochs=1, validation_data=None, update_distributions=False, distrib_update_every=1):
        res = []
        N = train_x.shape[0]
        steps_per_epoch = N // batch_size
        indicies = []
        for e_n in range(1, epochs+1):
          self.logger.info("==== Epoch " + str(e_n) + " started")
          for b_n in range(1, steps_per_epoch+1):
            if update_distributions and (b_n == 1 or b_n % distrib_update_every == 0):
              p = self._get_distribution(train_x, train_y)
              indicies = np.random.choice(N, batch_size, p=p)
            else:
              indicies = np.random.choice(N, batch_size)
            batch_x = np.take(train_x, indicies, axis=0)
            batch_y = np.take(train_y, indicies, axis=0)
            loss, acc = self.model.train_on_batch(batch_x, batch_y)
            #res += [(loss, acc)]
            if b_n % 10 == 0:
              self.logger.info(str(b_n) + "/" + str(steps_per_epoch) + " loss: " + str(loss) + " acc: " + str(acc))
              if validation_data is not None:
                res += self._test_on_validation(validation_data)
              
            
          self.logger.info(str(b_n) + "/" + str(steps_per_epoch) + " loss: " + str(loss) + " acc: " + str(acc))
         
          if validation_data is not None:
            self._test_on_validation(validation_data)
            
        return res

# %%
rais = OSGDTrainer(buildMnist())
# INFO:RAISTrainer:350/468 loss: 1.1657655 acc: 0.65625
# INFO:RAISTrainer:========== Validation loss: 0.54783016 acc: 0.8846
# INFO:RAISTrainer:360/468 loss: 1.2113941 acc: 0.625
# INFO:RAISTrainer:========== Validation loss: 0.5648057 acc: 0.8858
# INFO:RAISTrainer:370/468 loss: 0.8630071 acc: 0.75
# INFO:RAISTrainer:========== Validation loss: 0.50501096 acc: 0.8859
# INFO:RAISTrainer:380/468 loss: 0.87366056 acc: 0.7734375
# INFO:RAISTrainer:========== Validation loss: 0.51312596 acc: 0.9025
# INFO:RAISTrainer:390/468 loss: 0.92208856 acc: 0.734375
# INFO:RAISTrainer:========== Validation loss: 0.52281433 acc: 0.8802
# INFO:RAISTrainer:400/468 loss: 0.97533494 acc: 0.7109375
# INFO:RAISTrainer:========== Validation loss: 0.5010231 acc: 0.8904
# INFO:RAISTrainer:410/468 loss: 0.8964055 acc: 0.75
# INFO:RAISTrainer:========== Validation loss: 0.4853104 acc: 0.9097
# INFO:RAISTrainer:420/468 loss: 1.1696247 acc: 0.65625
# INFO:RAISTrainer:========== Validation loss: 0.55564433 acc: 0.8835
# INFO:RAISTrainer:430/468 loss: 1.1927979 acc: 0.6484375
# INFO:RAISTrainer:========== Validation loss: 0.5117527 acc: 0.8991
# INFO:RAISTrainer:440/468 loss: 1.0180488 acc: 0.6875
# INFO:RAISTrainer:========== Validation loss: 0.4839485 acc: 0.9004
# INFO:RAISTrainer:450/468 loss: 0.97112846 acc: 0.6640625
# INFO:RAISTrainer:========== Validation loss: 0.44038993 acc: 0.9094
# INFO:RAISTrainer:460/468 loss: 0.87872595 acc: 0.7265625
# INFO:RAISTrainer:========== Validation loss: 0.4429592 acc: 0.9022
# INFO:RAISTrainer:468/468 loss: 1.0292401 acc: 0.7109375
# INFO:RAISTrainer:========== Validation loss: 0.442006 acc: 0.9115

# %%
rais = OSGDTrainer(buildCifar())
res_sgd = rais.train(x_train_cifar, y_train_cifar,
                      validation_data=(x_test_cifar, y_test_cifar),
                      epochs=2, batch_size=256)
# Out:
# INFO:OSGDTrainer:==== Epoch 1 started
# INFO:OSGDTrainer:10/195 loss: 2.3061678 acc: 0.09765625
# INFO:OSGDTrainer:========== Validation loss: 2.3007336 acc: 0.0982
# INFO:OSGDTrainer:20/195 loss: 2.3072603 acc: 0.1015625
# INFO:OSGDTrainer:========== Validation loss: 2.299718 acc: 0.1008
# INFO:OSGDTrainer:30/195 loss: 2.3015347 acc: 0.109375
# INFO:OSGDTrainer:========== Validation loss: 2.2987812 acc: 0.1084
# INFO:OSGDTrainer:40/195 loss: 2.3090572 acc: 0.09375
# INFO:OSGDTrainer:========== Validation loss: 2.2979038 acc: 0.1144
# INFO:OSGDTrainer:50/195 loss: 2.3055403 acc: 0.1171875
# INFO:OSGDTrainer:========== Validation loss: 2.
acc: 0.15625
# INFO:OSGDTrainer:========== Validation loss: 2.2563655 acc: 0.1881
# INFO:OSGDTrainer:100/195 loss: 2.2659864 acc: 0.18359375
# INFO:OSGDTrainer:========== Validation loss: 2.2520642 acc: 0.1928
# INFO:OSGDTrainer:110/195 loss: 2.2670217 acc: 0.13671875
# INFO:OSGDTrainer:========== Validation loss: 2.2479608 acc: 0.1953
# INFO:OSGDTrainer:120/195 loss: 2.2560763 acc: 0.1328125
# INFO:OSGDTrainer:========== Validation loss: 2.2437532 acc: 0.2035
# INFO:OSGDTrainer:130/195 loss: 2.2264123 acc: 0.1953125
# INFO:OSGDTrainer:========== Validation loss: 2.2383928 acc: 0.205
# INFO:OSGDTrainer:140/195 loss: 2.2395463 acc: 0.1953125
# INFO:OSGDTrainer:========== Validation loss: 2.2336419 acc: 0.2084
# INFO:OSGDTrainer:150/195 loss: 2.268107 acc: 0.12109375
# INFO:OSGDTrainer:========== Validation loss: 2.2309637 acc: 0.2243
# INFO:OSGDTrainer:160/195 loss: 2.2266603 acc: 0.1796875
# INFO:OSGDTrainer:========== Validation loss: 2.2209845 acc: 0.2057
# INFO:OSGDTrainer:170/195 loss: 2.2268875 acc: 0.17578125
# INFO:OSGDTrainer:========== Validation loss: 2.215996 acc: 0.2183
# INFO:OSGDTrainer:180/195 loss: 2.2179847 acc: 0.15625
# INFO:OSGDTrainer:========== Validation loss: 2.211017 acc: 0.2293
# INFO:OSGDTrainer:190/195 loss: 2.198749 acc: 0.1875
# INFO:OSGDTrainer:========== Validation loss: 2.2018628 acc: 0.2229
# INFO:OSGDTrainer:195/195 loss: 2.1679044 acc: 0.234375
# INFO:OSGDTrainer:========== Validation loss: 2.1967368 acc: 0.2124

# %%
rais = OSGDTrainer(buildCifar())
res_sgd = rais.train(x_train_cifar, y_train_cifar,
                     validation_data=(x_test_cifar, y_test_cifar),
                     update_distributions=True, 
                     epochs=2, batch_size=256)
# Out:
# INFO:RAISTrainer:==== Epoch 1 started
# INFO:RAISTrainer:10/195 loss: 2.2937965 acc: 0.12109375
# INFO:RAISTrainer:========== Validation loss: 2.302585 acc: 0.1005
# INFO:RAISTrainer:20/195 loss: 2.3033197 acc: 0.109375
# INFO:RAISTrainer:========== Validation loss: 2.3016832 acc: 0.101
# INFO:RAISTrainer:30/195 loss: 2.3042238 acc: 0.1015625
# INFO:RAISTrainer:========== Validation loss: 2.3010702 acc: 0.0965
# INFO:RAISTrainer:40/195 loss: 2.2989793 acc: 0.11328125
# INFO:RAISTrainer:========== Validation loss: 2.3003778 acc: 0.0948
# INFO:RAISTrainer:50/195 loss: 2.2996209 acc: 0.09375
# INFO:RAISTrainer:========== Validation loss: 2.2996578 acc: 0.1009
# INFO:RAISTrainer:60/195 loss: 2.313193 acc: 0.12890625
# INFO:RAISTrainer:========== Validation loss: 2.299014 acc: 0.0994
# INFO:RAISTrainer:70/195 loss: 2.2980049 acc: 0.12890625
# INFO:RAISTrainer:========== Validation loss: 2.2983506 acc: 0.1062
# INFO:RAISTrainer:80/195 loss: 2.3114603 acc: 0.08984375
# INFO:RAISTrainer:========== Validation loss: 2.297959 acc: 0.1169
# INFO:RAISTrainer:90/195 loss: 2.3006597 acc: 0.12109375
# INFO:RAISTrainer:========== Validation loss: 2.2971485 acc: 0.1264
# INFO:RAISTrainer:100/195 loss: 2.295659 acc: 0.1171875
# INFO:RAISTrainer:========== Validation loss: 2.2964282 acc: 0.1331
# INFO:RAISTrainer:========== Validation loss: 2.2714674 acc: 0.1835
# INFO:RAISTrainer:120/195 loss: 2.266839 acc: 0.14453125
# INFO:RAISTrainer:========== Validation loss: 2.2683356 acc: 0.1932
# INFO:RAISTrainer:130/195 loss: 2.2806368 acc: 0.15625
# INFO:RAISTrainer:========== Validation loss: 2.2674284 acc: 0.2219
# INFO:RAISTrainer:140/195 loss: 2.278947 acc: 0.140625
# INFO:RAISTrainer:========== Validation loss: 2.2636187 acc: 0.2211
# INFO:RAISTrainer:150/195 loss: 2.2768602 acc: 0.14453125
# INFO:RAISTrainer:========== Validation loss: 2.2596965 acc: 0.218
# INFO:RAISTrainer:160/195 loss: 2.2664678 acc: 0.14453125
# INFO:RAISTrainer:========== Validation loss: 2.2574923 acc: 0.2326
# INFO:RAISTrainer:170/195 loss: 2.2678556 acc: 0.15234375
# INFO:RAISTrainer:========== Validation loss: 2.2518167 acc: 0.2352
# INFO:RAISTrainer:180/195 loss: 2.2648988 acc: 0.1640625
# INFO:RAISTrainer:========== Validation loss: 2.245147 acc: 0.214
# INFO:RAISTrainer:190/195 loss: 2.249659 acc: 0.19140625
# INFO:RAISTrainer:========== Validation loss: 2.2405088 acc: 0.2258
# INFO:RAISTrainer:195/195 loss: 2.2465158 acc: 0.18359375
# INFO:RAISTrainer:========== Validation loss: 2.2410347 acc: 0.2401

# %%
rais = OSGDTrainer(buildCifar())
res_sgd = rais.train(x_train_cifar, y_train_cifar,
                     validation_data=(x_test_cifar, y_test_cifar),
                     update_distributions=True,
                     distrib_update_every=10,
                     epochs=2, batch_size=256)
# Out:
# INFO:OSGDTrainer:==== Epoch 1 started
# INFO:OSGDTrainer:10/195 loss: 2.3197238 acc: 0.09375
# INFO:OSGDTrainer:========== Validation loss: 2.300793 acc: 0.0972
# INFO:OSGDTrainer:20/195 loss: 2.3056889 acc: 0.0703125
# INFO:OSGDTrainer:========== Validation loss: 2.2986968 acc: 0.1052
# INFO:OSGDTrainer:30/195 loss: 2.2938235 acc: 0.1171875
# INFO:OSGDTrainer:========== Validation loss: 2.2973719 acc: 0.1156
# INFO:OSGDTrainer:40/195 loss: 2.3046622 acc: 0.07421875
# INFO:OSGDTrainer:========== Validation loss: 2.2960794 acc: 0.116
# INFO:OSGDTrainer:50/195 loss: 2.2998488 acc: 0.0703125
# INFO:OSGDTrainer:========== Validation loss: 2.2945414 acc: 0.1194
# INFO:OSGDTrainer:60/195 loss: 2.2998717 acc: 0.09765625
# INFO:OSGDTrainer:========== Validation loss: 2.293266 acc: 0.1164
# INFO:OSGDTrainer:70/195 loss: 2.2989705 acc: 0.08984375
# INFO:OSGDTrainer:========== Validation loss: 2.292023 acc: 0.1106
# INFO:OSGDTrainer:80/195 loss: 2.302354 acc: 0.1015625
# INFO:OSGDTrainer:========== Validation loss: 2.2909265 acc: 0.1117
# INFO:OSGDTrainer:90/195 loss: 2.2939446 acc: 0.11328125
# INFO:OSGDTrainer:========== Validation loss: 2.2894046 acc: 0.113
# INFO:OSGDTrainer:100/195 loss: 2.2895403 acc: 0.1328125
# INFO:OSGDTrainer:========== Validation loss: 2.288227 acc: 0.1165
# INFO:OSGDTrainer:110/195 loss: 2.2941947 acc: 0.1171875
# INFO:OSGDTrainer:========== Validation loss: 2.
acc: 0.15625
# INFO:OSGDTrainer:========== Validation loss: 2.2106278 acc: 0.2142
# INFO:OSGDTrainer:130/195 loss: 2.25381 acc: 0.1875
# INFO:OSGDTrainer:========== Validation loss: 2.2004511 acc: 0.2134
# INFO:OSGDTrainer:140/195 loss: 2.3008726 acc: 0.12109375
# INFO:OSGDTrainer:========== Validation loss: 2.2010708 acc: 0.2398
# INFO:OSGDTrainer:150/195 loss: 2.2459831 acc: 0.12109375
# INFO:OSGDTrainer:========== Validation loss: 2.1882527 acc: 0.2289
# INFO:OSGDTrainer:160/195 loss: 2.2697365 acc: 0.1328125
# INFO:OSGDTrainer:========== Validation loss: 2.182923 acc: 0.241
# INFO:OSGDTrainer:170/195 loss: 2.2374628 acc: 0.1640625
# INFO:OSGDTrainer:========== Validation loss: 2.1786046 acc: 0.2504
# INFO:OSGDTrainer:180/195 loss: 2.2398186 acc: 0.15625
# INFO:OSGDTrainer:========== Validation loss: 2.1641307 acc: 0.2389
# INFO:OSGDTrainer:190/195 loss: 2.238907 acc: 0.15625
# INFO:OSGDTrainer:========== Validation loss: 2.1593175 acc: 0.2578
# INFO:OSGDTrainer:195/195 loss: 2.1594872 acc: 0.1796875
# INFO:OSGDTrainer:========== Validation loss: 2.1505368 acc: 0.2505

# %%
import logging
import numpy as np
logging.basicConfig(level=logging.DEBUG)

class RAISTrainer():

    def __init__(self, model):
        self.model = model
        self.logger = logging.getLogger("RAISTrainer")
    
        layer=-1
        grads = model.optimizer.get_gradients(model.total_loss, model.layers[layer].output)
        symb_inputs = (model._feed_inputs + model._feed_targets + model._feed_sample_weights)
        self.f_grads = K.function(symb_inputs, grads)
    
    def _get_grads(self, xs, ys):
        x, y, sample_weight = self.model._standardize_user_data(xs, ys)
        output_grad = self.f_grads(x + y + sample_weight)
        return output_grad

    def _get_distribution(self, xs, ys):
        n = xs.shape[0]
        k = 1000
        p = np.zeros(xs.shape[0])
        for i in range((n-1) // k + 1):
            fst = i*k
            snd = min(n, (i+1) * k)
            grads = self._get_grads(xs[fst:snd], ys[fst:snd])[0]
            v = np.linalg.norm(grads, axis=1)
            p[fst:snd] = v    
        return p / p.sum()

    def _test_on_validation(self, validation_data):
        valid_x, valid_y = validation_data
        loss, acc = self.model.test_on_batch(valid_x, valid_y)
        self.logger.info("========== Validation loss: " + str(loss) + " acc: " + str(acc))
        return [(loss, acc)]
      
    def train(self, train_x, train_y, batch_size=16, epochs=1, validation_data=None, update_distributions=False):
        res = []
        N = train_x.shape[0]
        steps_per_epoch = N // batch_size
        for e_n in range(1, epochs+1):
          self.logger.info("==== Epoch " + str(e_n) + " started")
          for b_n in range(1, steps_per_epoch+1):
            if update_distributions:
              p = self._get_distribution(train_x, train_y)
              indicies = np.random.choice(N, batch_size, p=p)
            else:
              indicies = np.random.choice(N, batch_size)
            batch_x = np.take(train_x, indicies, axis=0)
            batch_y = np.take(train_y, indicies, axis=0)
            loss, acc = self.model.train_on_batch(batch_x, batch_y)
            #res += [(loss, acc)]
            if b_n % 10 == 0:
              self.logger.info(str(b_n) + "/" + str(steps_per_epoch) + " loss: " + str(loss) + " acc: " + str(acc))
              if validation_data is not None:
                res += self._test_on_validation(validation_data)
              
          
          self.logger.info(str(b_n) + "/" + str(steps_per_epoch) + " loss: " + str(loss) + " acc: " + str(acc))
         
          if validation_data is not None:
            self._test_on_validation(validation_data)
            
        return res
